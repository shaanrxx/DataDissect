# %%
import requests
import pandas as pd

# %%
url = "https://sephora.p.rapidapi.com/products/list"

# %%
querystring = {"categoryId":"cat150006","pageSize":"70","currentPage":"1"}

# %%
headers = {
    "X-RapidAPI-Key": "9c2ded9108msha55090905dfe96dp152c1ajsnc4c239548328",
    "X-RapidAPI-Host": "sephora.p.rapidapi.com"
}

# %%
response = requests.get(url, headers=headers, params=querystring)

# %%
print(response.json())
# Create DataFrame from JSON response
df = pd.DataFrame.from_records(response.json()['products'])
df.to_csv('sephora_products.csv', index=False)
# Display first 5 rows of DataFrame
# Out:
# {'categoryId': 'cat150006', 'content': {'bestsellersTargetURL': '/best-selling-skin-care', 'justArrivedTargetURL': '/new-skin-care-products', 'region3': [{'componentName': 'Sephora Link Group Component', 'componentType': 9, 'enableTesting': False, 'links': [{'componentName': 'Sephora Link Component', 'componentType': 8, 'enableTesting': False, 'linkText': 'Skincare Quiz', 'name': 'app_link_skincare quiz', 'targetScreen': {'targetScreen': 'contentstore', 'targetValue': '50300057'}, 'testEnabled': False}, {'componentName': 'Sephora Link Component', 'componentType': 8, 'enableTesting': False, 'linkText': 'Luxury Skincare', 'name': 'app_link_luxe skincare', 'targetScreen': {'targetScreen': 'contentstore', 'targetValue': '102100018'}, 'testEnabled': False}, {'componentName': 'Sephora Link Component', 'componentType': 8, 'enableTesting': False, 'linkText': 'Skincare for Life', 'name': 'app_link_skincareforlife', 'targetScreen': {'targetScreen': 'contentstore', 'targetValue': '78900020'}, '
# ...

# %%
print(df.head())
# Out:
#         brandName                                         currentSku  \
# 0    The Ordinary  {'biExclusiveLevel': 'none', 'imageAltText': '...
# 1  Summer Fridays  {'badgeAltText': 'Clean at Sephora', 'biExclus...
# 2  Drunk Elephant  {'badgeAltText': 'Clean at Sephora', 'biExclus...
# 3    The Ordinary  {'badgeAltText': 'allure 2019 Best of Beauty A...
# 4          Tatcha  {'badgeAltText': 'Clean at Sephora', 'biExclus...
#
#                                          displayName  \
# 0        Niacinamide 10% + Zinc 1% Oil Control Serum
# 1                                    Lip Butter Balm
# 2  D-Bronzi™ Anti-Pollution Bronzing Drops with P...
# 3            Hyaluronic Acid 2% + B5 Hydrating Serum
# 4  The Dewy Skin Cream Plumping & Hydrating Moist...
#
#                                            heroImage  \
# 0  https://www.sephora.com/productimages/sku/s203...
# 1  https://www.sephora.com/productimages/sku/s249...
# 2  https://www.sephora.com/productimages/sku/s240...
# ...

# %%
querystring = {"number":"1","size":"50","country":"GB","language":"en-SG","filter_type":"cruelty free","query":"mica","sort":"price"}

headers = {
    "X-RapidAPI-Key": "9c2ded9108msha55090905dfe96dp152c1ajsnc4c239548328",
    "X-RapidAPI-Host": "sephora.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# Create DataFrame from JSON response
# df = pd.DataFrame.from_records(response.json()['products'])
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...

# %%
print(response.json())
# Create DataFrame from JSON response
df = pd.DataFrame.from_records(response.json()['products'])
df.to_csv('mica.csv', index=False)
# Display first 5 rows of DataFrame

# %%
# Display first 5 rows of DataFrame
print(df.head())

# %%
print(df.head())
