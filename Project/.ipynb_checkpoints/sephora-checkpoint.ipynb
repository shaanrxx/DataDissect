# %%
# import libraries
import requests
from bs4 import BeautifulSoup

import matplotlib.pyplot as plt
import functools as ft
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
r = requests.get("https://logicalharmony.net/cruelty-free-brands-at-sephora/")
soup = BeautifulSoup(r.text, 'html.parser')

# create an empty list that will store brands
brands = []

# create another list that will contain each list item still with the tags
rows = []

# get all list tags in entry-content part of the page (found by inspecting site)
brand_section1 = soup.find(class_='entry-content')
for brand in brand_section1.find_all('li'):
    # make sure brands are being extracted correctly
    # print(brand.text)
    # append each brand to the list of brands
    brands.append(brand.text)
    # keep the tags info in this list
    rows.append(brand)
    
len(brands)
# Out:
# 128

# %%
print(brands)
# Out:
# ['7 Virtues, The – 100% vegan', '8 Greens', 'Adwoa Beauty', 'Alpyn Beauty', 'Amika', 'Anastasia Beverly Hills', 'Antonym', 'Aquis', 'Athr Beauty (formerly Aether Beauty) – 100% vegan', 'Aveda\xa0100% vegan – It should be noted that they are cruelty-free, but their parent company is not.', 'Balm, The', 'bare Minerals (list of bare Minerals vegan products) – It should be noted that they are cruelty-free, but their parent company is not.', 'Beauty Chef, The', 'beautyblender', 'Bio Ionic', 'Biossance – 100% vegan', 'Bite Beauty – 100% vegan', 'bkr', 'Blinc', 'Boscia', 'Burt’s Bees –\xa0It should be noted that they are cruelty-free, but their parent company is not.', 'Buxom –\xa0It should be noted that they are cruelty-free, but their parent company is not.', 'Ceremonia – 100% vegan', 'Charlotte Tilbury (list of\xa0Charlotte Tilbury vegan products)', 'Ciaté London', 'COOLA\xa0(list of COOLA vegan products)', 'COVER FX – 100% vegan', 'Deborah Lippmann', 'Dermalogica\xa0– It should be noted
# ...

# %%
# create dataframe - start with just brands list, then adjust
cruelty_free_sephora_df = pd.DataFrame({'Brand_info': brands})   
cruelty_free_sephora_df.to_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/cruelty_free_sephora.csv', index=False)
cruelty_free_sephora_df.head()
# Out:
#                     Brand_info
# 0  7 Virtues, The – 100% vegan
# 1                     8 Greens
# 2                 Adwoa Beauty
# 3                 Alpyn Beauty
# 4                        Amika

# %%
# create a new column that tells whether or not a product is vegan
# create dataframe - start with just brands list, then adjust
cruelty_free_sephora_df['All_vegan'] = cruelty_free_sephora_df['Brand_info'].str.contains('100% vegan')
cruelty_free_sephora_df['Partial_vegan'] = cruelty_free_sephora_df['Brand_info'].str.contains('vegan product', case=False)

# %%
print(cruelty_free_sephora_df.All_vegan.sum())
print(cruelty_free_sephora_df.Partial_vegan.sum())
cruelty_free_sephora_df.head()
# Out:
# 34
# 11
#                     Brand_info  All_vegan  Partial_vegan
# 0  7 Virtues, The – 100% vegan       True          False
# 1                     8 Greens      False          False
# 2                 Adwoa Beauty      False          False
# 3                 Alpyn Beauty      False          False
# 4                        Amika      False          False

# %%
cruelty_free_sephora_df['Brand_info'].str.contains('Parent company').sum()
# Out:
# 0

# %%
# create a column that tells if a brand is owned by a company that is NOT cruelty free
cruelty_free_sephora_df['Bad_parent_company'] = cruelty_free_sephora_df['Brand_info'].str.contains('Parent company', case=False)

# %%
cruelty_free_only = cruelty_free_sephora_df[(cruelty_free_sephora_df['All_vegan'] == False) & (cruelty_free_sephora_df['Partial_vegan'] == False) & (cruelty_free_sephora_df['Bad_parent_company'] == False)]
num_cruelty_free = len(cruelty_free_only)
print(f"Number of brands that are just cruelty-free: {num_cruelty_free}")
# Out:
# Number of brands that are just cruelty-free: 70

# %%
# create a column that tells if a brand is owned by a company that is NOT cruelty free
cruelty_free_sephora_df['Bad_parent_company'] = cruelty_free_sephora_df['Brand_info'].str.contains('Parent company', case=False)

# %%
cruelty_free_sephora_df.head(20)
# Out:
#                                            Brand_info  All_vegan  \
# 0                         7 Virtues, The – 100% vegan       True
# 1                                            8 Greens      False
# 2                                        Adwoa Beauty      False
# 3                                        Alpyn Beauty      False
# 4                                               Amika      False
# 5                             Anastasia Beverly Hills      False
# 6                                             Antonym      False
# 7                                               Aquis      False
# 8   Athr Beauty (formerly Aether Beauty) – 100% vegan       True
# 9   Aveda 100% vegan – It should be noted that the...       True
# 10                                          Balm, The      False
# 11  bare Minerals (list of bare Minerals vegan pro...      False
# 12                                   Beauty Chef, The      False
# ...

# %%
cruelty_free_sephora_df.to_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/cruelty_free_sephora.csv', index=False)

# %%
# count the number of brands in each category
all_vegan_count = cruelty_free_sephora_df['All_vegan'].sum()
partial_vegan_count = cruelty_free_sephora_df['Partial_vegan'].sum()
bad_parent_count = cruelty_free_sephora_df['Bad_parent_company'].sum()

# create a bar plot of the counts
labels = ['All Vegan', 'Partially Vegan', 'Bad Parent Company']
counts = [all_vegan_count, partial_vegan_count, bad_parent_count]
plt.bar(labels, counts)
plt.title('Number of Brands by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
# count the number of brands in each category
all_vegan_count = cruelty_free_sephora_df['All_vegan'].sum()
partial_vegan_count = cruelty_free_sephora_df['Partial_vegan'].sum()
bad_parent_count = cruelty_free_sephora_df['Bad_parent_company'].sum()
cruelty_free_count = len(cruelty_free_only)

# create a bar plot of the counts
labels = ['All Vegan', 'Partially Vegan', 'Bad Parent Company', 'Cruelty-Free Only']
counts = [all_vegan_count, partial_vegan_count, bad_parent_count, cruelty_free_count]
plt.bar(labels, counts)
plt.title('Number of Brands by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
# count the number of brands in each category
all_vegan_count = cruelty_free_sephora_df['All_vegan'].sum()
partial_vegan_count = cruelty_free_sephora_df['Partial_vegan'].sum()
bad_parent_count = cruelty_free_sephora_df['Bad_parent_company'].sum()
cruelty_free_count = len(cruelty_free_only)

# create a pie chart of the counts
labels = ['All Vegan', 'Partially Vegan', 'Bad Parent Company', 'Cruelty-Free Only']
counts = [all_vegan_count, partial_vegan_count, bad_parent_count, cruelty_free_count]
colors = ['#5cb85c', '#f0ad4e', '#d9534f', '#5bc0de']
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Number of Brands by Category')
plt.show()

# %%
# r = requests.get("https://www.sephora.com/brands-list")
# soup = BeautifulSoup(r.text, 'html.parser')

# # create an empty list that will store brands
# brands = []

# # create another list that will contain each list item still with the tags
# rows = []

# # get all list tags in entry-content part of the page (found by inspecting site)
# brand_section1 = soup.find(class_='BrandsList')
# for brand in brand_section1.find_all('li'):
#     # make sure brands are being extracted correctly
#     # print(brand.text)
#     # append each brand to the list of brands
#     brands.append(brand.text)
#     # keep the tags info in this list
#     rows.append(brand)
    
# len(brands)

# %%
# # Get Response of "brandlist" Website from Sephora
# band_lst_link = "https://www.sephora.com/brands-list"
# response = requests.get(band_lst_link)

# # Use BeautifulSoup
# soup = BeautifulSoup(response.content, 'html.parser')

# # Scraping brand links and save them into a list
# brand_link_lst = []

# # create another list that will contain each list item still with the tags
# rows = []
# main_box = soup.find_all(attrs={"data-comp": "BrandsList "})[0]
# for brand in main_box.find_all('li'):
#     brand_link_lst.append("https://www.sephora.com" +
#                           brand.a.attrs['href']+"/all?pageSize=300")

# brand_list_lst.append(brand.text)
# rows.append(brand)
# len(brands)

# %%
from bs4 import BeautifulSoup
import requests

html = """<div id="brands-A" data-dcy-id="0.5519653433701255"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent " data-dcy-id="0.3030951730199525"></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.06632818066343349"><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">A</span><ul class="css-f4b3v4" data-dcy-id="0.9582641762530772"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/abbott" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.08135089145789531"><span data-dcy-id="0.8781072898597801">ABBOTT</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/acqua-di-parma" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.8554023544899001"><span data-dcy-id="0.8148338733465688">Acqua di Parma</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/adwoa-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.7168276146445436"><span data-dcy-id="0.10971181453362022">adwoa beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/aerin-perfume" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.082580887221676"><span data-dcy-id="0.15976284598276358">AERIN</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/algenist" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.04500129905465422"><span data-dcy-id="0.28077018425276323">Algenist</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/alpha-h" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.3528561228193585"><span data-dcy-id="0.2560771140570479">Alpha-H</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/alpyn-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9168626742968757"><span data-dcy-id="0.44081385728785105">alpyn beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/alterna" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.7076609702357026"><span data-dcy-id="0.4417778956577867">ALTERNA Haircare</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ami-cole" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.4615860500353459"><span data-dcy-id="0.13484006489551148">Ami Colé</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/amika" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.04734263074868861"><span data-dcy-id="0.11128459066419571">amika</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/anastasia-beverly-hills" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.7640204526512124"><span data-dcy-id="0.7254990347792576">Anastasia Beverly Hills</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/aquis" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.6727735860650161"><span>Aquis</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/giorgio-armani-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9678388351608556"><span data-dcy-id="0.4093024310515434">Armani Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/artist-couture" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.5807154473193838"><span data-dcy-id="0.5405733369362093">Artist Couture</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/atelier-cologne" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.13180627284935786"><span data-dcy-id="0.12003355833899065">Atelier Cologne</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/augustinus-bader" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.7639769705857207"><span data-dcy-id="0.9958098271862859">Augustinus Bader</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/azzaro" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9522510457350102"><span>Azzaro</span></a></li></ul></div></div>"""

soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})

# Extract the brand names
brands_a = [tag.find("span").text.strip() for tag in brand_tags]

print(brands_a)
# Out:
# ['ABBOTT', 'Acqua di Parma', 'adwoa beauty', 'AERIN', 'Algenist', 'Alpha-H', 'alpyn beauty', 'ALTERNA Haircare', 'Ami Colé', 'amika', 'Anastasia Beverly Hills', 'Aquis', 'Armani Beauty', 'Artist Couture', 'Atelier Cologne', 'Augustinus Bader', 'Azzaro']

# %%
print(len(brands))
# Out:
# 128

# %%
from bs4 import BeautifulSoup
import requests

html = """<div id="brands-B" data-dcy-id="0.5962121891059904"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.16364668260868775">B</span><ul class="css-f4b3v4" data-dcy-id="0.8968527578226597"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/bareminerals" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.580084453856293"><span>bareMinerals</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/basma" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.01263414377120431"><span>BASMA</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/the-beauty-chef" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.6303416746192052"><span>The Beauty Chef</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/beautybio" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9262817454223224"><span>BeautyBio</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/beautyblender" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.18069415396960897"><span>beautyblender</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/belif" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>belif</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/benefit-cosmetics" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span data-dcy-id="0.9873823206811361">Benefit Cosmetics</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/berdoues" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.8764567761713726"><span data-dcy-id="0.31018097699519975">BERDOUES</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/better-not-younger" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.5854206851268839"><span data-dcy-id="0.1119076899931315">Better Not Younger</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/bio-ionic" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.6874297007058203"><span>Bio Ionic</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/biossance" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.050877494998780914"><span data-dcy-id="0.8935494752842474">Biossance</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/blinc" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9202733874374174"><span>Blinc</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/bobbi-brown" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span data-dcy-id="0.5930514511637326">Bobbi Brown</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/bon-parfumeur" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9442226941995355"><span>Bon Parfumeur</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/bondi-boost" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.6985765946538613"><span>BondiBoost</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/boysmells" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.7225693567908738"><span>Boy Smells</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/bread-beauty-supply" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9788077998610205"><span data-dcy-id="0.11518247323141861">BREAD BEAUTY SUPPLY</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/briogeo" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9547845972802638"><span>Briogeo</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/bumble-bumble" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Bumble and bumble</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/burberry" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>BURBERRY</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/buxom" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Buxom</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/by-rosie-jane" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>By Rosie Jane</span></a></li></ul></div></div>"""

soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})

# Extract the brand names
brands_b = [tag.find("span").text.strip() for tag in brand_tags]

print(brands_b)
# Out:
# ['bareMinerals', 'BASMA', 'The Beauty Chef', 'BeautyBio', 'beautyblender', 'belif', 'Benefit Cosmetics', 'BERDOUES', 'Better Not Younger', 'Bio Ionic', 'Biossance', 'Blinc', 'Bobbi Brown', 'Bon Parfumeur', 'BondiBoost', 'Boy Smells', 'BREAD BEAUTY SUPPLY', 'Briogeo', 'Bumble and bumble', 'BURBERRY', 'Buxom', 'By Rosie Jane']

# %%
html= """<div id="brands-C" data-dcy-id="0.6427321881366601"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">C</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/caliray" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9831024888354616"><span>caliray</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/calvin-klein" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Calvin Klein</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/canopy" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>CANOPY</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/capri-blue" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Capri Blue</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/carolina-herrera" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Carolina Herrera</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/caudalie" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Caudalie</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/cay-skin" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>CAY SKIN</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ceremonia" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Ceremonia</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/chanel" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>CHANEL</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/charlotte-tilbury" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Charlotte Tilbury</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/chloe" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Chloé</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/christian-louboutin-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Christian Louboutin</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/christophe-robin" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Christophe Robin</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ciate" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Ciaté London</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/cinema-secrets" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Cinema Secrets</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/clarins" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Clarins</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/clean-reserve" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>CLEAN RESERVE</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/clinique" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>CLINIQUE</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/coach" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>COACH</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/color-wow" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>COLOR WOW</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/commodity" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Commodity</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/community-sixty-six" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Community Sixty-Six</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/coola-suncare" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>COOLA</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/crown-affair" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Crown Affair</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/curlsmith" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Curlsmith</span></a></li></ul></div></div>"""
soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})

# Extract the brand names
brands_c = [tag.find("span").text.strip() for tag in brand_tags]

print(brands_c)
# Out:
# ['caliray', 'Calvin Klein', 'CANOPY', 'Capri Blue', 'Carolina Herrera', 'Caudalie', 'CAY SKIN', 'Ceremonia', 'CHANEL', 'Charlotte Tilbury', 'Chloé', 'Christian Louboutin', 'Christophe Robin', 'Ciaté London', 'Cinema Secrets', 'Clarins', 'CLEAN RESERVE', 'CLINIQUE', 'COACH', 'COLOR WOW', 'Commodity', 'Community Sixty-Six', 'COOLA', 'Crown Affair', 'Curlsmith']

# %%
html= """<div id="brands-D"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">D</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dae" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>dae</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dam-dam" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>DAMDAM</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/danessa-myricks-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Danessa Myricks Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/deborah-lippmann" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Deborah Lippmann</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dedcool" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>DedCool</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/derek-lam-10-crosby" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>DEREK LAM 10 CROSBY</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dermaflash" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>DERMAFLASH</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dermalogica" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dermalogica</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dior" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dior</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dolce-gabbana" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dolce&amp;Gabbana</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dominique-cosmetics" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>DOMINIQUE COSMETICS</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/donna-karan" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Donna Karan</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dphue" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>dpHUE</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dr-barbara-sturm" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dr. Barbara Sturm</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dr-brandt-skincare" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dr. Brandt Skincare</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dr-dennis-gross-skincare" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dr. Dennis Gross Skincare</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dr-jart" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dr. Jart+</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dr-lara-devgan-scientific-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dr. Lara Devgan Scientific Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dr-zenovia-skin-care" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dr. Zenovia Skincare</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/drunk-elephant" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Drunk Elephant</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/drybar" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Drybar</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/duo" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>DUO</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/dyson" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Dyson</span></a></li></ul></div></div>, <div id="brands-E"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">E</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/eadem" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>EADEM</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/eight-bob" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Eight &amp; Bob</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ellis-brooklyn" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Ellis Brooklyn</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/erno-laszlo" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Erno Laszlo</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/estee-lauder" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Estée Lauder</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/evian" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Evian</span></a></li></ul></div></div>, <div id="brands-F" data-dcy-id="0.2723374160304719"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">F</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/fable-mane" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Fable &amp; Mane</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/facegym" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>FaceGym</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/farmacy" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Farmacy</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/fashion-fair" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Fashion Fair</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/fenty-beauty-rihanna" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Fenty Beauty by Rihanna</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/fenty-skin-rihanna" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Fenty Skin</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/first-aid-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>First Aid Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/flora-bast" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Flora + Bast</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/floral-street" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Floral Street</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/foreo" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>FOREO</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/forvr-mood" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>FORVR Mood</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/freck-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Freck Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/fresh" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>fresh</span></a></li></ul></div></div>, <div id="brands-G"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">G</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ghd" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>ghd</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/gisou" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Gisou</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/givenchy" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Givenchy</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/glamnetic" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Glamnetic</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/glo-science" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>GLO Science</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/glossier" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Glossier</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/glow-recipe" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Glow Recipe</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/good-dye-young" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Good Dye Young</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/goop" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>goop</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/grace-eleyae" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Grace Eleyae</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/grande-cosmetics" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Grande Cosmetics</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/gucci" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Gucci</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/guerlain" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>GUERLAIN</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/gxve-by-gwen-stefani" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>GXVE BY GWEN STEFANI</span></a></li></ul></div></div>, <div id="brands-G"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">G</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ghd" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>ghd</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/gisou" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Gisou</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/givenchy" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Givenchy</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/glamnetic" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Glamnetic</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/glo-science" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>GLO Science</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/glossier" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Glossier</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/glow-recipe" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Glow Recipe</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/good-dye-young" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Good Dye Young</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/goop" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>goop</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/grace-eleyae" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Grace Eleyae</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/grande-cosmetics" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Grande Cosmetics</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/gucci" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Gucci</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/guerlain" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>GUERLAIN</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/gxve-by-gwen-stefani" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>GXVE BY GWEN STEFANI</span></a></li></ul></div></div>,<div id="brands-H" data-dcy-id="0.5903097595308981"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.16101957126570965"><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.5859174940768936">H</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/habit" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>HABIT</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/hanni" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Hanni</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/haus-labs-by-lady-gaga" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>HAUS LABS BY LADY GAGA</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/henry-rose" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>Henry Rose</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/herbivore-botanicals" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Herbivore</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/heretic" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>HERETIC</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/hermes" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>HERMÈS</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/hourglass" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.24441664230967586"><span>Hourglass</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/house-of-lashes" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>House of Lashes</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/huda-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>HUDA BEAUTY</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/hum-nutrition" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.1596267069167998"><span data-dcy-id="0.0741631563747811">HUM Nutrition</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/hyper-skin" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.8177950286663973"><span data-dcy-id="0.4859792898921764">Hyper Skin</span></a></li></ul></div></div>""" 

soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})

# Extract the brand names
brands_defgh = [tag.find("span").text.strip() for tag in brand_tags]

print(brands_defgh)
# Out:
# ['dae', 'DAMDAM', 'Danessa Myricks Beauty', 'Deborah Lippmann', 'DedCool', 'DEREK LAM 10 CROSBY', 'DERMAFLASH', 'Dermalogica', 'Dior', 'Dolce&Gabbana', 'DOMINIQUE COSMETICS', 'Donna Karan', 'dpHUE', 'Dr. Barbara Sturm', 'Dr. Brandt Skincare', 'Dr. Dennis Gross Skincare', 'Dr. Jart+', 'Dr. Lara Devgan Scientific Beauty', 'Dr. Zenovia Skincare', 'Drunk Elephant', 'Drybar', 'DUO', 'Dyson', 'EADEM', 'Eight & Bob', 'Ellis Brooklyn', 'Erno Laszlo', 'Estée Lauder', 'Evian', 'Fable & Mane', 'FaceGym', 'Farmacy', 'Fashion Fair', 'Fenty Beauty by Rihanna', 'Fenty Skin', 'First Aid Beauty', 'Flora + Bast', 'Floral Street', 'FOREO', 'FORVR Mood', 'Freck Beauty', 'fresh', 'ghd', 'Gisou', 'Givenchy', 'Glamnetic', 'GLO Science', 'Glossier', 'Glow Recipe', 'Good Dye Young', 'goop', 'Grace Eleyae', 'Grande Cosmetics', 'Gucci', 'GUERLAIN', 'GXVE BY GWEN STEFANI', 'ghd', 'Gisou', 'Givenchy', 'Glamnetic', 'GLO Science', 'Glossier', 'Glow Recipe', 'Good Dye Young', 'goop', 'Grace Eleyae', 'Grande Cosmeti
# ...

# %%
html = """<div id="brands-I"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">I</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/iconic-london" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Iconic London</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/igk" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>IGK</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ilia" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>ILIA</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/iluminage" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>iluminage</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/incredible" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>INC.redible</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/indie-lee" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Indie Lee</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/the-inkey-list" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>The INKEY List</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/innbeauty-project" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>iNNBEAUTY PROJECT</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/innisfree" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>innisfree</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/isle-paradise" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Isle of Paradise</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/it-cosmetics" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>IT Cosmetics</span></a></li></ul></div></div>, <div id="brands-J"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">J</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/jack-black" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Jack Black</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/jillian-dempsey" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Jillian Dempsey</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/jimmy-choo" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>JIMMY CHOO</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/jlo-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>JLo Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/jo-malone-london" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Jo Malone London</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/john-varvatos" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>John Varvatos</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/josie-maran" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Josie Maran</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/jouer-cosmetics" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Jouer Cosmetics</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/juicy-couture" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Juicy Couture</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/juliette-has-a-gun" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Juliette Has a Gun</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/jvn" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>JVN</span></a></li></ul></div></div>, <div id="brands-K"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">K</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/k18-hair" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>K18 Biomimetic Hairscience</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kaja" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kaja</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/kate-mcleod" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kate McLeod</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kate-somerville" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kate Somerville</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kayali-by-huda" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>KAYALI</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kerastase" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kérastase</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kiehls" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kiehl's Since 1851</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kilian" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>KILIAN Paris</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kitsch" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kitsch</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/knc-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>KNC Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/koh-gen-do" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Koh Gen Do</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kopari" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kopari</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kora-organics" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>KORA Organics</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/korres" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>KORRES</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kosas" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kosas</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kulfi" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Kulfi</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/kvd-vegan-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>KVD Beauty</span></a></li></ul></div></div>"""

soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})

# Extract the brand names
brands_ijk = [tag.find("span").text.strip() for tag in brand_tags]

print(brands)
# Out:
# ['7 Virtues, The – 100% vegan', '8 Greens', 'Adwoa Beauty', 'Alpyn Beauty', 'Amika', 'Anastasia Beverly Hills', 'Antonym', 'Aquis', 'Athr Beauty (formerly Aether Beauty) – 100% vegan', 'Aveda\xa0100% vegan – It should be noted that they are cruelty-free, but their parent company is not.', 'Balm, The', 'bare Minerals (list of bare Minerals vegan products) – It should be noted that they are cruelty-free, but their parent company is not.', 'Beauty Chef, The', 'beautyblender', 'Bio Ionic', 'Biossance – 100% vegan', 'Bite Beauty – 100% vegan', 'bkr', 'Blinc', 'Boscia', 'Burt’s Bees –\xa0It should be noted that they are cruelty-free, but their parent company is not.', 'Buxom –\xa0It should be noted that they are cruelty-free, but their parent company is not.', 'Ceremonia – 100% vegan', 'Charlotte Tilbury (list of\xa0Charlotte Tilbury vegan products)', 'Ciaté London', 'COOLA\xa0(list of COOLA vegan products)', 'COVER FX – 100% vegan', 'Deborah Lippmann', 'Dermalogica\xa0– It should be noted
# ...

# %%
html= """<div id="brands-L"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">L</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/l-occitane" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>L'Occitane</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/l-oreal-professionnel" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>L'Oreal Professionnel</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/la-mer" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>La Mer</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/lancome" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Lancôme</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/laneige" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>LANEIGE</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/lash-food" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>LASHFOOD</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/laura-mercier" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Laura Mercier</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/lawless" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>LAWLESS</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/lilah-b" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>lilah b.</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/lilly-lashes" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Lilly Lashes</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/living-proof" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Living Proof</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/luna-daily" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>Luna Daily</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/lys-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>LYS Beauty</span></a></li></ul></div></div>, <div id="brands-M"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">M</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/macrene-actives" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>MACRENE actives</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/maison-louis-marie" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Maison Louis Marie</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/maison-margiela" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Maison Margiela</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/make-up-for-ever" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>MAKE UP FOR EVER</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/the-maker" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>The Maker</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/makeup-by-mario" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>MAKEUP BY MARIO</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/mara" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>MARA</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/marc-jacobs-fragrances" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Marc Jacobs Fragrances</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/mario-badescu" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Mario Badescu</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/maude" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>maude</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/melanin-haircare" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Melanin Haircare</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/melt-cosmetics" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Melt Cosmetics</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/merit" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>MERIT</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/milk-makeup" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Milk Makeup</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/mizani" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Mizani</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/montblanc" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Montblanc</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/moon-juice" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Moon Juice</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/moroccanoil" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Moroccanoil</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/mount-lai" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Mount Lai</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/mugler" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Mugler</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/murad" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Murad</span></a></li></ul></div></div>, <div id="brands-N"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">N</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/nails-inc" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>NAILS INC.</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/narciso-rodriguez" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Narciso Rodriguez</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/nars" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>NARS</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/natasha-denona" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Natasha Denona</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/naturally-serious" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Naturally Serious</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/necessaire" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Nécessaire</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/nest" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>NEST New York</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/nette" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>Nette</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/nudestix" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>NUDESTIX</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/the-nue-co" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>The Nue Co.</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/nuface" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>NuFACE</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/nurse-jamie" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Nurse Jamie</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/nutrafol" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Nutrafol</span></a></li></ul></div></div>"""

soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})

# Extract the brand names
brands_lmn = [tag.find("span").text.strip() for tag in brand_tags]

print(brands_lmn)
# Out:
# ["L'Occitane", "L'Oreal Professionnel", 'La Mer', 'Lancôme', 'LANEIGE', 'LASHFOOD', 'Laura Mercier', 'LAWLESS', 'lilah b.', 'Lilly Lashes', 'Living Proof', 'Luna Daily', 'LYS Beauty', 'MACRENE actives', 'Maison Louis Marie', 'Maison Margiela', 'MAKE UP FOR EVER', 'The Maker', 'MAKEUP BY MARIO', 'MARA', 'Marc Jacobs Fragrances', 'Mario Badescu', 'maude', 'Melanin Haircare', 'Melt Cosmetics', 'MERIT', 'Milk Makeup', 'Mizani', 'Montblanc', 'Moon Juice', 'Moroccanoil', 'Mount Lai', 'Mugler', 'Murad', 'NAILS INC.', 'Narciso Rodriguez', 'NARS', 'Natasha Denona', 'Naturally Serious', 'Nécessaire', 'NEST New York', 'Nette', 'NUDESTIX', 'The Nue Co.', 'NuFACE', 'Nurse Jamie', 'Nutrafol']

# %%
html = """<div id="brands-O"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">O</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/original-mineral" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>O&amp;M</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/olaplex" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Olaplex</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ole-henriksen" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>OLEHENRIKSEN</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/one-size-by-patrick-starrr" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>ONE/SIZE by Patrick Starrr</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/the-ordinary" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>The Ordinary</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/oribe" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Oribe</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/makeup-eraser" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>The Original MakeUp Eraser</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/origins" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Origins</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/otherland" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>OTHERLAND</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ouai-haircare" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>OUAI</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/the-outset" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>The Outset</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/overose" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Overose</span></a></li></ul></div></div>, <div id="brands-P"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">P</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/paco-rabanne" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Paco Rabanne</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/pat-mcgrath-labs" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>PAT McGRATH LABS</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/patrick-ta" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>PATRICK TA</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/pattern-beauty-by-tracee-ellis-ross" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>PATTERN by Tracee Ellis Ross</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/paulas-choice" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Paula's Choice</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/peace-out" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Peace Out</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/peter-thomas-roth" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Peter Thomas Roth</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/philosophy" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>philosophy</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/phluid" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>The Phluid Project</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/phlur" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>PHLUR</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/pmd" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>PMD</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/prada" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Prada</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/prima" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Prima</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/proven-skincare" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>PROVEN Skincare</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/pureology" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Pureology</span></a></li></ul></div></div>, <div id="brands-R"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">R</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/rahua" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Rahua</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ralph-lauren" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Ralph Lauren</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ranavat" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>RANAVAT</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/rare-beauty-by-selena-gomez" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Rare Beauty by Selena Gomez</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/refy-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>REFY</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ren" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>REN Clean Skincare</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/reverie" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Reverie</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/ries" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>RIES</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/rms-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>rms beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/rose-inc" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>ROSE INC</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/rose-ingleton-md" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>ROSE Ingleton MD</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/rosebud-perfume-co" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Rosebud Perfume Co.</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/rossano-ferretti-parma" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Rossano Ferretti Parma</span></a></li></ul></div></div>"""
soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})

# Extract the brand names
brands_opr = [tag.find("span").text.strip() for tag in brand_tags]

print(brands_opr)
# Out:
# ['O&M', 'Olaplex', 'OLEHENRIKSEN', 'ONE/SIZE by Patrick Starrr', 'The Ordinary', 'Oribe', 'The Original MakeUp Eraser', 'Origins', 'OTHERLAND', 'OUAI', 'The Outset', 'Overose', 'Paco Rabanne', 'PAT McGRATH LABS', 'PATRICK TA', 'PATTERN by Tracee Ellis Ross', "Paula's Choice", 'Peace Out', 'Peter Thomas Roth', 'philosophy', 'The Phluid Project', 'PHLUR', 'PMD', 'Prada', 'Prima', 'PROVEN Skincare', 'Pureology', 'Rahua', 'Ralph Lauren', 'RANAVAT', 'Rare Beauty by Selena Gomez', 'REFY', 'REN Clean Skincare', 'Reverie', 'RIES', 'rms beauty', 'ROSE INC', 'ROSE Ingleton MD', 'Rosebud Perfume Co.', 'Rossano Ferretti Parma']

# %%
html = """<div id="brands-S"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">S</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/saie" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Saie</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/saint-jane-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Saint Jane</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sakara-life" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Sakara Life</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/selfless-by-hyram" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Selfless by Hyram</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sephora-collection" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>SEPHORA COLLECTION</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sephora-favorites" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Sephora Favorites</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/shani-darden" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Shani Darden Skin Care</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/shark-beauty" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>Shark Beauty</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/shiseido" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Shiseido</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/shu-uemura" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>shu uemura</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/simihaze" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>SIMIHAZE BEAUTY</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sk-ii" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>SK-II</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/skin-laundry" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Skin Laundry</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/skinfix" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Skinfix</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/skylar" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Skylar</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/slip" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Slip</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/smashbox" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Smashbox</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sobel-skincare-rx" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>SOBEL SKIN Rx</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sol-de-janeiro" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Sol de Janeiro</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/soleil-toujours" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Soleil Toujours</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sourse" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>Sourse</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/st-tropez-tanning-essentials" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>St. Tropez</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/stila" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>stila</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/stripes" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>Stripes</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/strivectin" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>StriVectin</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sulwhasoo" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Sulwhasoo</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/summer-fridays" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Summer Fridays</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sunday-ii-sunday" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>SUNDAY II SUNDAY</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/sunday-riley" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Sunday Riley</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/supergoop" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Supergoop!</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/superzero" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>superzero</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/susteau" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Susteau</span></a></li></ul></div></div>, <div id="brands-T"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">T</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/t3" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>T3</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tabu" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent "><span>Tabu</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tan-luxe" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>TAN-LUXE</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tarte" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>tarte</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tata-harper" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Tata Harper</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tatcha" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Tatcha</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/this-works" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>This Works</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tocca" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>TOCCA</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tom-ford" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>TOM FORD</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/too-faced" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Too Faced</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/topicals" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Topicals</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tory-burch" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Tory Burch</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/touchland" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Touchland</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tower-28" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Tower 28 Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tula-skincare" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>TULA Skincare</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/tweezerman" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Tweezerman</span></a></li></ul></div></div>, <div id="brands-U"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">U</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/urban-decay" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Urban Decay</span></a></li></ul></div></div> """
soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})

# Extract the brand names
brands_stu = [tag.find("span").text.strip() for tag in brand_tags]

print(brands_stu)
# Out:
# ['Saie', 'Saint Jane', 'Sakara Life', 'Selfless by Hyram', 'SEPHORA COLLECTION', 'Sephora Favorites', 'Shani Darden Skin Care', 'Shark Beauty', 'Shiseido', 'shu uemura', 'SIMIHAZE BEAUTY', 'SK-II', 'Skin Laundry', 'Skinfix', 'Skylar', 'Slip', 'Smashbox', 'SOBEL SKIN Rx', 'Sol de Janeiro', 'Soleil Toujours', 'Sourse', 'St. Tropez', 'stila', 'Stripes', 'StriVectin', 'Sulwhasoo', 'Summer Fridays', 'SUNDAY II SUNDAY', 'Sunday Riley', 'Supergoop!', 'superzero', 'Susteau', 'T3', 'Tabu', 'TAN-LUXE', 'tarte', 'Tata Harper', 'Tatcha', 'This Works', 'TOCCA', 'TOM FORD', 'Too Faced', 'Topicals', 'Tory Burch', 'Touchland', 'Tower 28 Beauty', 'TULA Skincare', 'Tweezerman', 'Urban Decay']

# %%
html = """<div id="brands-V"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">V</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/valentino" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.42315843976454404"><span>Valentino</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/vegamour" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.05142782448503014"><span>Vegamour</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/velour-lashes" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.575395806458965"><span>Velour Lashes</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/verb-hair-care" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.4544540108372961"><span data-dcy-id="0.8695966981171217">Verb</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/versace" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.8213484672963896"><span data-dcy-id="0.9212248272970276">Versace</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/viktor-rolf" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.0018490054259723276"><span data-dcy-id="0.2010167907036442">Viktor&amp;Rolf</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/violet-voss" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Violet Voss</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/viori" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Viori</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/virtue" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Virtue</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/viseart" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Viseart</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/vitruvi" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Vitruvi</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/volition-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Volition Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/voluspa" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Voluspa</span></a></li></ul></div></div>, <div id="brands-W"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent "><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent ">W</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/wander-beauty" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Wander Beauty</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/waso" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>WASO</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/westman-atelier" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Westman Atelier</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/wishful-by-huda" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>Wishful</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/chris-collins" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>World of Chris Collins</span></a></li></ul></div></div>, <div id="brands-Y"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.12186533269436017"><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.7610008591961344">Y</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/youth-to-the-people" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.10910567922898684"><span>Youth To The People</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/yves-saint-laurent" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.6920387400127306"><span>Yves Saint Laurent</span></a></li></ul></div></div>, <div id="brands-#" data-dcy-id="0.7618674667694851"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.027938722250145487"><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.07611946684473603">#</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/19-69" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.3028660556263296"><span>19-69</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/5-sens" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9710020591680624"><span>5 SENS</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/54-thrones" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.060970014168551856"><span data-dcy-id="0.0966620832714069">54 Thrones</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/7-virtues" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.26589566744362814"><span>The 7 Virtues</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/8greens" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent "><span>8Greens</span></a></li></ul></div></div>, <div id="brands-#" data-dcy-id="0.7618674667694851"><div class="css-1y7ih1d eanm77i0" data-comp="Divider StyledComponent "></div><div class="css-2bl0p6 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.027938722250145487"><span class="css-1bfknn4 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.07611946684473603">#</span><ul class="css-f4b3v4"><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/19-69" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.3028660556263296"><span>19-69</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/5-sens" class="css-yohf49 eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.9710020591680624"><span>5 SENS</span><span class="css-epvm6"><span>﻿</span><span class="css-w0e0a7 eanm77i0" data-comp="Flag StyledComponent BaseComponent ">NEW</span></span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/54-thrones" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.060970014168551856"><span data-dcy-id="0.0966620832714069">54 Thrones</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/7-virtues" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.26589566744362814"><span>The 7 Virtues</span></a></li><li class="css-1d67h5w"><a data-at="brand_link" href="/brand/8greens" class="css-8yx8xn eanm77i0" data-comp="StyledComponent BaseComponent " data-dcy-id="0.42913137663307843"><span>8Greens</span></a></li></ul></div></div>,  """
soup = BeautifulSoup(html, "html.parser")

# Find all the 'a' tags with the attribute 'data-at="brand_link"'
brand_tags = soup.find_all("a", attrs={"data-at": "brand_link"})
# Extract the brand names
brands_vwxy = [tag.find("span").text.strip() for tag in brand_tags]

print(brands_vwxy)
# Out:
# ['Valentino', 'Vegamour', 'Velour Lashes', 'Verb', 'Versace', 'Viktor&Rolf', 'Violet Voss', 'Viori', 'Virtue', 'Viseart', 'Vitruvi', 'Volition Beauty', 'Voluspa', 'Wander Beauty', 'WASO', 'Westman Atelier', 'Wishful', 'World of Chris Collins', 'Youth To The People', 'Yves Saint Laurent', '19-69', '5 SENS', '54 Thrones', 'The 7 Virtues', '8Greens', '19-69', '5 SENS', '54 Thrones', 'The 7 Virtues', '8Greens']

# %%
brands = brands_a + brands_b + brands_c + brands_defgh + brands_ijk + brands_lmn + brands_opr + brands_stu + brands_vwxy

# %%
print(brands)
# Out:
# ['ABBOTT', 'Acqua di Parma', 'adwoa beauty', 'AERIN', 'Algenist', 'Alpha-H', 'alpyn beauty', 'ALTERNA Haircare', 'Ami Colé', 'amika', 'Anastasia Beverly Hills', 'Aquis', 'Armani Beauty', 'Artist Couture', 'Atelier Cologne', 'Augustinus Bader', 'Azzaro', 'bareMinerals', 'BASMA', 'The Beauty Chef', 'BeautyBio', 'beautyblender', 'belif', 'Benefit Cosmetics', 'BERDOUES', 'Better Not Younger', 'Bio Ionic', 'Biossance', 'Blinc', 'Bobbi Brown', 'Bon Parfumeur', 'BondiBoost', 'Boy Smells', 'BREAD BEAUTY SUPPLY', 'Briogeo', 'Bumble and bumble', 'BURBERRY', 'Buxom', 'By Rosie Jane', 'caliray', 'Calvin Klein', 'CANOPY', 'Capri Blue', 'Carolina Herrera', 'Caudalie', 'CAY SKIN', 'Ceremonia', 'CHANEL', 'Charlotte Tilbury', 'Chloé', 'Christian Louboutin', 'Christophe Robin', 'Ciaté London', 'Cinema Secrets', 'Clarins', 'CLEAN RESERVE', 'CLINIQUE', 'COACH', 'COLOR WOW', 'Commodity', 'Community Sixty-Six', 'COOLA', 'Crown Affair', 'Curlsmith', 'dae', 'DAMDAM', 'Danessa Myricks Beauty', 'Deborah Lippm
# ...

# %%
print(len(brands))
# Out:
# 351

# %%
# create dataframe - start with just brands list, then adjust
all_brands_sephora_df = pd.DataFrame({'Brand_info': brands})   
all_brands_sephora_df.to_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_sephora.csv', index=False)
all_brands_sephora_df.head(30)
# Out:
#                  Brand_info
# 0                    ABBOTT
# 1            Acqua di Parma
# 2              adwoa beauty
# 3                     AERIN
# 4                  Algenist
# 5                   Alpha-H
# 6              alpyn beauty
# 7          ALTERNA Haircare
# 8                  Ami Colé
# 9                     amika
# 10  Anastasia Beverly Hills
# 11                    Aquis
# 12            Armani Beauty
# 13           Artist Couture
# 14          Atelier Cologne
# 15         Augustinus Bader
# 16                   Azzaro
# 17             bareMinerals
# 18                    BASMA
# 19          The Beauty Chef
# 20                BeautyBio
# 21            beautyblender
# 22                    belif
# 23        Benefit Cosmetics
# 24                 BERDOUES
# 25       Better Not Younger
# 26                Bio Ionic
# 27                Biossance
# 28                    Blinc
# 29              Bobbi Brown

# %%
# load data from CSV files
all_brands_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_sephora.csv')
cruelty_free_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/cruelty_free_sephora.csv')

# check if brand names appear in both data frames
all_brands_sephora_df['cruelty_free'] = all_brands_sephora_df['Brand_info'].isin(cruelty_free_sephora_df['Brand_info'])

# display table
print(all_brands_sephora_df.head(40))
# Out:
#                  Brand_info  cruelty_free
# 0                    ABBOTT         False
# 1            Acqua di Parma         False
# 2              adwoa beauty         False
# 3                     AERIN         False
# 4                  Algenist         False
# 5                   Alpha-H         False
# 6              alpyn beauty         False
# 7          ALTERNA Haircare         False
# 8                  Ami Colé         False
# 9                     amika         False
# 10  Anastasia Beverly Hills          True
# 11                    Aquis          True
# 12            Armani Beauty         False
# 13           Artist Couture         False
# 14          Atelier Cologne         False
# 15         Augustinus Bader         False
# 16                   Azzaro         False
# 17             bareMinerals         False
# 18                    BASMA         False
# 19          The Beauty Chef         False
# 20                BeautyBio         False
# ...

# %%
# Count the number of cruelty-free and non-cruelty-free brands
num_cruelty_free = len(cruelty_free_sephora_df)
num_non_cruelty_free = len(all_brands_sephora_df) - num_cruelty_free

# Create a list of values and labels for the pie chart
values = [num_cruelty_free, num_non_cruelty_free]
labels = ['Cruelty-free', 'Non-cruelty-free']

# Set the color for each section of the pie chart
colors = ['pink', 'purple']

# Create the pie chart
plt.pie(values, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# Add a title to the pie chart
plt.title('Percentage of Cruelty-free Brands in Sephora')

# Show the pie chart
plt.show()

# %%
# Create the pie chart with additional arguments
plt.pie(values, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, shadow=True, explode=(0.05, 0), wedgeprops={'linewidth': 2, 'edgecolor': 'white'})

# Add a title to the pie chart
plt.title('Percentage of Cruelty-free Brands verified by Logic Harmony in Sephora')

# Show the pie chart
plt.show()

# %%
import pandas as pd
# Load data from CSV files
peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/peta.csv')
cruelty_free_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/cruelty_free_sephora.csv')

# Convert brand names to lowercase for case-insensitive comparison
peta_df['Brand_info'] = peta_df['Brand_info'].str.lower()
cruelty_free_sephora_df['Brand_info'] = cruelty_free_sephora_df['Brand_info'].str.lower()

# Check if brand names appear in both data frames
peta_df['cruelty_free'] = peta_df['Brand_info'].isin(cruelty_free_sephora_df['Brand_info'])

# Calculate the number of cruelty-free brands out of all brands
num_cruelty_free_brands = peta_df['cruelty_free'].sum()

# Calculate the percentage of cruelty-free brands out of all brands
percentage_cruelty_free = (num_cruelty_free_brands / len(peta_df)) * 100

# Calculate the percentage of non-cruelty-free brands out of all brands
percentage_non_cruelty_free = 100 - percentage_cruelty_free

# Print the results
print(f"Number of cruelty-free brands out of all brands: {num_cruelty_free_brands}")
print(f"Percentage of cruelty-free brands out of all brands: {percentage_cruelty_free:.2f}%")
print(f"Percentage of non-cruelty-free brands out of all brands: {percentage_non_cruelty_free:.2f}%")
# Out:
# Number of cruelty-free brands out of all brands: 12
# Percentage of cruelty-free brands out of all brands: 0.19%
# Percentage of non-cruelty-free brands out of all brands: 99.81%

# %%
# Load data from CSV files
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_sephora.csv')

# Convert brand names to lowercase for case-insensitive comparison
all_peta_df['Brand_info'] = all_peta_df['Brand_info'].str.lower()
all_brands_sephora_df['Brand_info'] = all_brands_sephora_df['Brand_info'].str.lower()

# Add a column to store the result of cruelty-free check
all_brands_sephora_df['cruelty_free'] = all_brands_sephora_df['Brand_info'].isin(all_peta_df['Brand_info'])

# Print the updated DataFrame
print(all_brands_sephora_df.head(50))


# Print the number of cruelty-free products and their percentages
print(f"Number of cruelty-free products: {num_cruelty_free}")
print(f"Percentage of cruelty-free products: {percentage_cruelty_free:.2f}%")
print(f"Percentage of non-cruelty-free products: {percentage_non_cruelty_free:.2f}%")
# Out:
#                  Brand_info  cruelty_free
# 0                    abbott          True
# 1            acqua di parma         False
# 2              adwoa beauty         False
# 3                     aerin         False
# 4                  algenist         False
# 5                   alpha-h         False
# 6              alpyn beauty         False
# 7          alterna haircare         False
# 8                  ami colé         False
# 9                     amika          True
# 10  anastasia beverly hills          True
# 11                    aquis         False
# 12            armani beauty         False
# 13           artist couture          True
# 14          atelier cologne         False
# 15         augustinus bader         False
# 16                   azzaro         False
# 17             bareminerals          True
# 18                    basma         False
# 19          the beauty chef         False
# 20                beautybio          True
# ...

# %%
# Out:
# Number of cruelty-free products: 128
# Percentage of cruelty-free products: 15.67%
# Percentage of non-cruelty-free products: 84.33%

# %%
plt.title('Cruelty-Free Status of Brands Stocked by Ulta')

# Count the number of true and false values in the 'cruelty_free' column
cruelty_free_counts = all_brands_sephora_df['cruelty_free'].value_counts()

# Create labels for the pie chart
labels = ['Cruelty-Free', 'Not Cruelty-Free']

# Create colors for the pie chart
colors = ['green', 'red']

# Create the pie chart
plt.pie(cruelty_free_counts, labels=labels, colors=colors, autopct='%1.1f%%')


# Display the chart
plt.show()

# Add a title

# Count the number of true and false values in the 'cruelty_free' column
cruelty_free_counts = all_brands_sephora_df['cruelty_free'].value_counts()

# Calculate the total number of products
total_products = len(all_brands_sephora_df)

# Calculate the percentage of cruelty-free products
percentage_cruelty_free = (cruelty_free_counts[True] / total_products) * 100

# Calculate the percentage of non-cruelty-free products
percentage_non_cruelty_free = (cruelty_free_counts[False] / total_products) * 100

# Print the results
print(f"Number of cruelty-free products: {cruelty_free_counts[True]}")
print(f"Percentage of cruelty-free products: {percentage_cruelty_free:.2f}%")
print(f"Number of non-cruelty-free products: {cruelty_free_counts[False]}")
print(f"Percentage of non-cruelty-free products: {percentage_non_cruelty_free:.2f}%")
# Out:
# Number of cruelty-free products: 55
# Percentage of cruelty-free products: 15.67%
# Number of non-cruelty-free products: 296
# Percentage of non-cruelty-free products: 84.33%

# %%
import pandas as pd

# Load data from CSV files
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_sephora.csv')

# Convert brand names to lowercase for case-insensitive comparison
all_peta_df['Brand_info'] = all_peta_df['Brand_info'].str.lower()
all_brands_sephora_df['Brand_info'] = all_brands_sephora_df['Brand_info'].str.lower()

# Add a column to store the result of cruelty-free check
all_brands_sephora_df['cruelty_free'] = all_brands_sephora_df['Brand_info'].isin(all_peta_df['Brand_info'])

# Calculate the number of cruelty-free products
num_cruelty_free = all_brands_sephora_df['cruelty_free'].sum()

# Calculate the percentage of cruelty-free products out of all products
percentage_cruelty_free = (num_cruelty_free / len(all_brands_sephora_df)) * 100

# Calculate the percentage of non-cruelty-free products out of all products
percentage_non_cruelty_free = 100 - percentage_cruelty_free

# Print the updated DataFrame
print(all_brands_sephora_df.head(50))

# Print the number of cruelty-free products and their percentages
print(f"Number of cruelty-free products: {num_cruelty_free}")
print(f"Percentage of cruelty-free products: {percentage_cruelty_free:.2f}%")
print(f"Percentage of non-cruelty-free products: {percentage_non_cruelty_free:.2f}%")
# Out:
#                  Brand_info  cruelty_free
# 0                    abbott          True
# 1            acqua di parma         False
# 2              adwoa beauty         False
# 3                     aerin         False
# 4                  algenist         False
# 5                   alpha-h         False
# 6              alpyn beauty         False
# 7          alterna haircare         False
# 8                  ami colé         False
# 9                     amika          True
# 10  anastasia beverly hills          True
# 11                    aquis         False
# 12            armani beauty         False
# 13           artist couture          True
# 14          atelier cologne         False
# 15         augustinus bader         False
# 16                   azzaro         False
# 17             bareminerals          True
# 18                    basma         False
# 19          the beauty chef         False
# 20                beautybio          True
# ...

# %%
import pandas as pd

# Load data from CSV files
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_sephora.csv')

# Convert brand names to lowercase for case-insensitive comparison
all_peta_df['Brand_info'] = all_peta_df['Brand_info'].str.lower()
all_brands_sephora_df['Brand_info'] = all_brands_sephora_df['Brand_info'].str.lower()

# Add a column to store the result of cruelty-free check
all_brands_sephora_df['cruelty_free'] = all_brands_sephora_df['Brand_info'].isin(all_peta_df['Brand_info'])

# Calculate the number of cruelty-free products
num_cruelty_free = all_brands_sephora_df['cruelty_free'].sum()

# Calculate the percentage of cruelty-free products out of all products
percentage_cruelty_free = (num_cruelty_free / len(all_brands_sephora_df)) * 100

# Calculate the percentage of non-cruelty-free products out of all products
percentage_non_cruelty_free = 100 - percentage_cruelty_free

# Print the updated DataFrame
print(all_brands_sephora_df.head(50))

# Print the number of cruelty-free products and their percentages
print(f"Number of cruelty-free products: {num_cruelty_free}")
print(f"Percentage of cruelty-free products: {percentage_cruelty_free:.2f}%")
print(f"Percentage of non-cruelty-free products: {percentage_non_cruelty_free:.2f}%")
# Out:
#                  Brand_info  cruelty_free
# 0                    abbott          True
# 1            acqua di parma         False
# 2              adwoa beauty         False
# 3                     aerin         False
# 4                  algenist         False
# 5                   alpha-h         False
# 6              alpyn beauty         False
# 7          alterna haircare         False
# 8                  ami colé         False
# 9                     amika          True
# 10  anastasia beverly hills          True
# 11                    aquis         False
# 12            armani beauty         False
# 13           artist couture          True
# 14          atelier cologne         False
# 15         augustinus bader         False
# 16                   azzaro         False
# 17             bareminerals          True
# 18                    basma         False
# 19          the beauty chef         False
# 20                beautybio          True
# ...

# %%
import matplotlib.pyplot as plt

# Calculate the number of cruelty-free and non-cruelty-free products
num_cruelty_free = all_brands_sephora_df['cruelty_free'].sum()
num_non_cruelty_free = len(all_brands_sephora_df) - num_cruelty_free

# Create labels for the pie chart
labels = ['Cruelty-Free', 'Non-Cruelty-Free']

# Create colors for the pie chart
colors = ['#57B89E', '#E37222']

# Create the pie chart
plt.pie([num_cruelty_free, num_non_cruelty_free], labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# Add a title
plt.title('Cruelty-Free Products in Sephora Verified my PETA')

# Add a legend
plt.legend()

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the number of cruelty-free and non-cruelty-free products
num_cruelty_free = all_brands_sephora_df['cruelty_free'].sum()
num_non_cruelty_free = len(all_brands_sephora_df) - num_cruelty_free

# Create labels for the pie chart
labels = ['Cruelty-Free', 'Non-Cruelty-Free']

# Create colors for the pie chart
colors = ['#57B89E', '#E37222']

# Define the explode values (0 for non-exploded slices, a positive value for the desired explosion)
explode = [0.1, 0]

# Create the pie chart with 3D effect
plt.pie([num_cruelty_free, num_non_cruelty_free], labels=labels, colors=colors, autopct='%1.1f%%', startangle=100, explode=explode, shadow=True)

# Add a title
plt.title('Cruelty-Free Products in Sephora Verified by PETA')

# Add a legend
plt.legend()

# Display the chart
plt.show()
