# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import functools as ft
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
# Send a GET request to the PETA page listing brands that don't test on animals
url = 'https://crueltyfree.peta.org/companies-dont-test/?per_page=all'
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# Find the unordered list containing the brands
list_container = soup.find('ul', {'class': 'search-results'})

# Initialize an empty list to store the brands
brands = []

# Iterate over the list items
for item in list_container.find_all('li'):
    # Extract the brand name
    brand = item.text.strip()
    brands.append(brand)

# Print the list of brands that don't test on animals
print(brands)
# Out:
# ['_SkinLabo\n\n\n\n\n\n\n\nL', 'ОгgапiсаLiЬrа\n\n\n\n\n\n\n\n\n\n\nL', '100% Pure', '1121 Apothecary\n\n\n\n\n\n\n\n\n\n\nL', '12 Grabs\n\n\n\n\n\n\n\nL', 'L', '123 Nourish Me\n\n\n\n\n\n\n\nL', '180 Innovations\n\n\n\n\n\n\n\n\n\n\nL', 'SanMelix Laboratories', '19th Volume Cosmetics Corp.\n\n\n\n\n\n\n\nL', '21 Drop', '21 Drops\n\n\n\n\n\n\n\n\n\n\nL', '23 Beauty Limited', '23Beauty Paris\n\n\n\n\n\n\n\n\n\n\nL', '24K Cosmetics\n\n\n\n\n\n\n\n\n\n\nL', '28 Litsea\n\n\n\n\n\n\n\nL', '2E Organic\n\n\n\n\n\n\n\nL', '2kcommerce\n\n\n\n\n\n\n\n\n\n\nL', '2nd Love Cosmetics\n\n\n\n\n\n\n\nL', '2SHERO KOZMETIK IMALAT TIC\n\n\n\n\n\n\n\n\n\n\nL', '3107 Skincare\n\n\n\n\n\n\n\nL', '3INA\n\n\n\n\n\n\n\n\n\n\nL', '3rd Rock Essentials\n\n\n\n\n\n\n\nL', '4Beauty Group\n\n\n\n\n\n\n\nL', '4EVER MAGIC COSMETICS\n\n\n\n\n\n\n\n\n\n\nL', '4mula', '4organic', '4ourclimate', '4peoplewhocare UG\n\n\n\n\n\n\n\nL', '5 Star Shave Club', '5 Stars Shave Club\n\n\n\n\n\n\n\n\n\n\nL', '516 Polish\n\n\n\n\n\n
# ...

# %%
print(len(brands))
# Out:
# 6273

# %%
# Clean the data
brands = [brand.split('\n')[0] for brand in brands]  # Remove extra text after the brand name

# Create a DataFrame
peta_df = pd.DataFrame({'Brand_info': brands})
peta_df.to_csv("C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/peta.csv", index=False)

# Print the DataFrame
print(peta_df)
# Out:
#                   Brand_info
# 0                  _SkinLabo
# 1              ОгgапiсаLiЬrа
# 2                  100% Pure
# 3            1121 Apothecary
# 4                   12 Grabs
# ...                      ...
# 6268  Zosimos Botanicals LLC
# 6269              Zue Beauty
# 6270            Zuii Organic
# 6271          Zuzu Cosmetics
# 6272                 Zyderma
#
# [6273 rows x 1 columns]

# %%
# Send a GET request to the PETA page listing brands that don't test on animals
url = 'https://crueltyfree.peta.org/vegan-companies/?alpha=&per_page=all'
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# Find the unordered list containing the brands
list_container = soup.find('ul', {'class': 'search-results'})

# Initialize an empty list to store the brands
brands = []

# Iterate over the list items
for item in list_container.find_all('li'):
    # Extract the brand name
    brand = item.text.strip()
    brands.append(brand)

# Print the list of brands that don't test on animals
print(brands)
# Out:
# ['ОгgапiсаLiЬrа\n\n\n\n\n\n\n\n\n\n\nL', '1121 Apothecary\n\n\n\n\n\n\n\n\n\n\nL', 'L', '180 Innovations\n\n\n\n\n\n\n\n\n\n\nL', 'SanMelix Laboratories', '21 Drop', '21 Drops\n\n\n\n\n\n\n\n\n\n\nL', '23Beauty Paris\n\n\n\n\n\n\n\n\n\n\nL', '24K Cosmetics\n\n\n\n\n\n\n\n\n\n\nL', '2kcommerce\n\n\n\n\n\n\n\n\n\n\nL', '2SHERO KOZMETIK IMALAT TIC\n\n\n\n\n\n\n\n\n\n\nL', '3INA\n\n\n\n\n\n\n\n\n\n\nL', '4EVER MAGIC COSMETICS\n\n\n\n\n\n\n\n\n\n\nL', '4mula', '4organic', '4ourclimate', '5 Stars Shave Club\n\n\n\n\n\n\n\n\n\n\nL', '516 Polish\n\n\n\n\n\n\n\n\n\n\nL', '66°30\n\n\n\n\n\n\n\n\n\n\nL', '707 Flora\n\n\n\n\n\n\n\n\n\n\nL', '786 Cosmetics\n\n\n\n\n\n\n\n\nF', '7elements\n\n\n\n\n\n\n\n\n\n\nL', '7TRUE™\n\n\n\n\n\n\n\n\n\n\nL', '82°E (DPKA UNIVERSAL CONSUMER VENTURES PRIVATE LIMITED)\n\n\n\n\n\n\n\n\n\n\nL', 'A Good Fur Day', 'A.P. CHEM\n\n\n\n\n\n\n\n\n\n\nL', 'A Perfume Organic\n\n\n\n\n\n\n\n\n\n\nL', 'A Touch of Class Beauty\n\n\n\n\n\n\n\n\n\n\nL', 'A101- YENİ MAGAZACILIK\n\
# ...

# %%
print(len(brands))
# Out:
# 3373

# %%
# Clean the data
brands = [brand.split('\n')[0] for brand in brands]  # Remove extra text after the brand name

# Create a DataFrame
vegan_peta_df = pd.DataFrame({'Brand_info': brands})
vegan_peta_df.to_csv("C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/vegan_peta.csv", index=False)

# Print the DataFrame
print(vegan_peta_df)
# Out:
#                  Brand_info
# 0             ОгgапiсаLiЬrа
# 1           1121 Apothecary
# 2                         L
# 3           180 Innovations
# 4     SanMelix Laboratories
# ...                     ...
# 3368              Zoey Koko
# 3369                   ZoiY
# 3370              ZolaTerra
# 3371             Zue Beauty
# 3372                Zyderma
#
# [3373 rows x 1 columns]

# %%
import pandas as pd

# Load data from vegan_peta.csv
vegan_peta_df = pd.read_csv("C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/vegan_peta.csv")

# Load data from peta.csv
peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/peta.csv')

# Concatenate the DataFrames
all_peta_df = pd.concat([vegan_peta_df, peta_df], ignore_index=True)

# Drop duplicates based on the 'Brand_info' column
all_peta_df = all_peta_df.drop_duplicates(subset='Brand_info')

# Save the merged DataFrame as all_peta.csv
all_peta_df.to_csv("C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv", index=False)

# Print the merged DataFrame
print(all_peta_df)
# Out:
#                   Brand_info
# 0              ОгgапiсаLiЬrа
# 1            1121 Apothecary
# 2                          L
# 3            180 Innovations
# 4      SanMelix Laboratories
# ...                      ...
# 9639              Zoo On Yoo
# 9640    Zorah biocosmétiques
# 9641  Zosimos Botanicals LLC
# 9643            Zuii Organic
# 9644          Zuzu Cosmetics
#
# [6263 rows x 1 columns]

# %%
# Load data from CSV files
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_ulta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_ulta.csv')

# Convert brand names to lowercase for case-insensitive comparison
all_peta_df['Brand_info'] = all_peta_df['Brand_info'].str.lower()
all_brands_ulta_df['Brand_info'] = all_brands_ulta_df['Brand_info'].str.lower()

# Check if brand names appear in both data frames
cruelty_free_brands_df = peta_df.merge(all_brands_ulta_df, how='inner', left_on='Brand_info', right_on='Brand_info')

# Get the names of all cruelty-free brands available on Ulta
cruelty_free_brand_names = cruelty_free_brands_df['Brand_info'].tolist()

# Print the names of all cruelty-free brands available on Ulta
print("Names of all cruelty-free brands available on Ulta:")
for brand in cruelty_free_brand_names:
    print(brand)
# Out:
# Names of all cruelty-free brands available on Ulta:
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty
# r.e.m. beauty

# %%
print(all_peta_df.head(30))
# Out:
#                                            Brand_info
# 0                                       огgапiсаliьrа
# 1                                     1121 apothecary
# 2                                                   l
# 3                                     180 innovations
# 4                               sanmelix laboratories
# 5                                             21 drop
# 6                                            21 drops
# 7                                      23beauty paris
# 8                                       24k cosmetics
# 9                                          2kcommerce
# 10                         2shero kozmetik imalat tic
# 11                                               3ina
# 12                              4ever magic cosmetics
# 13                                              4mula
# 14                                           4organic
# 15                                        4ourclimate
# ...

# %%
# Load data from CSV files
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_cultbeauty_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_cultbeauty.csv')

# Convert brand names to lowercase for case-insensitive comparison
all_peta_df['Brand_info'] = all_peta_df['Brand_info'].str.lower()
all_brands_cultbeauty_df['Brand_info'] = all_brands_cultbeauty_df['Brand_info'].str.lower()

# Check if brand names appear in both data frames
all_peta_df['cruelty_free'] = all_peta_df['Brand_info'].isin(all_brands_cultbeauty_df['Brand_info'])

# Calculate the number of cruelty-free brands out of all brands
num_cruelty_free_brands = all_peta_df['cruelty_free'].sum()

# Calculate the percentage of cruelty-free brands out of all brands
percentage_cruelty_free = (num_cruelty_free_brands / len(all_brands_cultbeauty_df)) * 100

# Calculate the percentage of non-cruelty-free brands out of all brands
percentage_non_cruelty_free = 100 - percentage_cruelty_free

# Print the results
print(f"Number of cruelty-free brands out of all brands: {num_cruelty_free_brands}")
print(f"Percentage of cruelty-free brands out of all brands: {percentage_cruelty_free:.2f}%")
print(f"Percentage of non-cruelty-free brands out of all brands: {percentage_non_cruelty_free:.2f}%")
# Out:
# Number of cruelty-free brands out of all brands: 46
# Percentage of cruelty-free brands out of all brands: 15.54%
# Percentage of non-cruelty-free brands out of all brands: 84.46%

# %% [markdown]
# CULT BEAUTY

# %%
# Calculate the number of non-cruelty-free brands
num_non_cruelty_free_brands = len(all_brands_cultbeauty_df) - num_cruelty_free_brands

# Create a list of labels for the pie chart
labels = ['Cruelty-Free', 'Non-Cruelty-Free']

# Create a list of values for the pie chart
values = [num_cruelty_free_brands, num_non_cruelty_free_brands]

# Create a pie chart
plt.pie(values, labels=labels, autopct='%1.1f%%')

# Add a title to the pie chart
plt.title('Cruelty-Free vs Non-Cruelty-Free Brands in Cult Beauty verified by PETA')

# Display the pie chart
plt.show()

# %%
# Define colors for the pie chart slices
colors = ['#55a868', '#c44e52']

# Define explode values to emphasize a particular slice (optional)
explode = [0.1, 0]

# Create a pie chart
plt.pie(values, labels=labels, explode=explode, colors=colors, autopct='%1.1f%%', startangle=90, shadow=True)

# Add a title and legend to the pie chart
plt.title('Cruelty-Free vs Non-Cruelty-Free Brands in Cult Beauty verified by PETA')
plt.legend(loc='upper right', labels=labels)

# Set aspect ratio to make the pie chart a circle
plt.axis('equal')

# Display the pie chart
plt.show()

# %%
# Load data from CSV files
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_sephora.csv')

# Convert brand names to lowercase for case-insensitive comparison
all_peta_df['Brand_info'] = all_peta_df['Brand_info'].str.lower()
all_brands_sephora_df['Brand_info'] = all_brands_sephora_df['Brand_info'].str.lower()

# Check if brand names appear in both data frames
all_peta_df['cruelty_free'] = all_peta_df['Brand_info'].isin(all_brands_sephora_df['Brand_info'])

# Calculate the number of cruelty-free brands out of all brands
num_cruelty_free_brands = all_peta_df['cruelty_free'].sum()

# Calculate the percentage of cruelty-free brands out of all brands
percentage_cruelty_free = (num_cruelty_free_brands / len(all_brands_sephora_df)) * 100

# Calculate the percentage of non-cruelty-free brands out of all brands
percentage_non_cruelty_free = 100 - percentage_cruelty_free

# Print the results
print(f"Number of cruelty-free brands out of all brands: {num_cruelty_free_brands}")
print(f"Percentage of cruelty-free brands out of all brands: {percentage_cruelty_free:.2f}%")
print(f"Percentage of non-cruelty-free brands out of all brands: {percentage_non_cruelty_free:.2f}%")
# Out:
# Number of cruelty-free brands out of all brands: 52
# Percentage of cruelty-free brands out of all brands: 19.70%
# Percentage of non-cruelty-free brands out of all brands: 80.30%

# %%
import pandas as pd


# Read the CSV files into dataframes
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_sephora.csv')

# Check if brand names appear in both data frames and print "True" if they appear in the peta_df dataframe
all_brands_sephora_df['appears_in_all_peta_df'] = all_brands_sephora_df['Brand_info'].isin(all_peta_df['Brand_info'])
print(all_brands_sephora_df['appears_in_all_peta_df'])
# display table
print(all_brands_sephora_df.head(40))
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 259    False
# 260    False
# 261    False
# 262    False
# 263    False
# Name: appears_in_all_peta_df, Length: 264, dtype: bool
#                  Brand_info  appears_in_all_peta_df
# 0                about-face                   False
# 1                    Acnemy                   False
# 2                     Aēsop                   False
# 3            Allies of Skin                    True
# 4   Anastasia Beverly Hills                    True
# 5             Ariana Grande                   False
# 6                   As I Am                    True
# 7                     Aśani                   False
# 8            Aurelia London                   False
# 9                     Avène                   False
# 10            Babe Original                   False
# 11                 BaByliss                   False
# 12             Babyliss Pro                   False
# ...

# %%
# Calculate the length of brands that appear in the peta_df dataframe
num_brands_appear_in_all_peta_df = all_brands_sephora_df['appears_in_all_peta_df'].sum()

# Print the length of brands that appear in the peta_df dataframe
print(f"Number of brands appearing in peta_df: {num_brands_appear_in_all_peta_df}")
# Out:
# Number of brands appearing in peta_df: 46

# %%
# common_brands = peta_df[peta_df['cruelty_free']]['Brand_info'].values
# print(common_brands)

# %% [markdown]
# SEPHORA

# %%
# Calculate the number of non-cruelty-free brands
num_non_cruelty_free_brands = len(all_brands_sephora_df) - num_cruelty_free_brands

# Create a list of labels for the pie chart
labels = ['Cruelty-Free', 'Non-Cruelty-Free']

# Create a list of values for the pie chart
values = [num_cruelty_free_brands, num_non_cruelty_free_brands]

# Create a pie chart
plt.pie(values, labels=labels, autopct='%1.1f%%')

# Add a title to the pie chart
plt.title('Cruelty-Free vs Non-Cruelty-Free Brands in Cult Sephora verified by PETA')

# Display the pie chart
plt.show()

# %%
# Create the pie chart with additional arguments
plt.pie(values, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, shadow=True, explode=(0.05, 0), wedgeprops={'linewidth': 2, 'edgecolor': 'white'})

# Add a title to the pie chart
plt.title('Percentage of Cruelty-free Brands verfiied by PETA in Sephora')

# Show the pie chart
plt.show()

# %%
# Load data from CSV files
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_ulta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_ulta.csv')

# Convert brand names to lowercase for case-insensitive comparison
all_peta_df['Brand_info'] = all_peta_df['Brand_info'].str.lower()
all_brands_ulta_df['Brand_info'] = all_brands_ulta_df['Brand_info'].str.lower()

# Check if brand names appear in both data frames
all_peta_df['cruelty_free'] = all_peta_df['Brand_info'].isin(all_brands_ulta_df['Brand_info'])

# Calculate the number of cruelty-free brands out of all brands
num_cruelty_free_brands = all_peta_df['cruelty_free'].sum()

# Calculate the percentage of cruelty-free brands out of all brands
percentage_cruelty_free = (num_cruelty_free_brands / len(all_brands_ulta_df)) * 100

# Calculate the percentage of non-cruelty-free brands out of all brands
percentage_non_cruelty_free = 100 - percentage_cruelty_free

# Print the results
print(f"Number of cruelty-free brands out of all brands: {num_cruelty_free_brands}")
print(f"Percentage of cruelty-free brands out of all brands: {percentage_cruelty_free:.2f}%")
print(f"Percentage of non-cruelty-free brands out of all brands: {percentage_non_cruelty_free:.2f}%")
# Out:
# Number of cruelty-free brands out of all brands: 18
# Percentage of cruelty-free brands out of all brands: 1.07%
# Percentage of non-cruelty-free brands out of all brands: 98.93%

# %%
# Load data from CSV files
all_peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_peta.csv')
all_brands_ulta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_ulta.csv')

# Convert brand names to lowercase for case-insensitive comparison
all_peta_df['Brand_info'] = all_peta_df['Brand_info'].str.lower()
all_brands_ulta_df['Brand_info'] = all_brands_ulta_df['Brand_info'].str.lower()

# Check if brand names appear in both data frames
all_peta_df['cruelty_free'] = all_peta_df['Brand_info'].isin(all_brands_ulta_df['Brand_info'])

# Filter the dataframe to get only cruelty-free brands
cruelty_free_brands_df = all_peta_df[all_peta_df['cruelty_free']]

# Get the names of all cruelty-free brands
cruelty_free_brand_names = cruelty_free_brands_df['Brand_info'].tolist()

# Print the names of all cruelty-free brands
print("Names of all cruelty-free brands:")
for brand in cruelty_free_brand_names:
    print(brand)
# Out:
# Names of all cruelty-free brands:
# babo botanicals
# dashing diva
# earth harbor
# e.l.f. cosmetics
# hairtamin
# i dew care
# mad hippie
# ofra cosmetics
# pacifica
# r.e.m. beauty
# sacheu
# tan-luxe
# we are paradoxx
# iconic london
# jack black
# j.cat beauty
# tangle teezer
# ulta beauty collection

# %%
# Load data from CSV files
peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/peta.csv')
all_brands_ulta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_ulta.csv')

# Convert brand names to lowercase for case-insensitive comparison
peta_df['Brand_info'] = peta_df['Brand_info'].str.lower()
all_brands_ulta_df['Brand_info'] = all_brands_ulta_df['Brand_info'].str.lower()

# Remove special characters from brand names
peta_df['Brand_info'] = peta_df['Brand_info'].str.replace('[^\w\s]+', '')
all_brands_ulta_df['Brand_info'] = all_brands_ulta_df['Brand_info'].str.replace('[^\w\s]+', '')

# Check if brand names appear in both data frames
peta_df['cruelty_free'] = peta_df['Brand_info'].isin(all_brands_ulta_df['Brand_info'])

# Calculate the number of cruelty-free brands out of all brands
num_cruelty_free_brands = peta_df['cruelty_free'].sum()

# Calculate the percentage of cruelty-free brands out of all brands
percentage_cruelty_free = (num_cruelty_free_brands / len(all_brands_ulta_df)) * 100

# Calculate the percentage of non-cruelty-free brands out of all brands
percentage_non_cruelty_free = 100 - percentage_cruelty_free

# Print the number of cruelty-free brands without special characters
print(f"Number of cruelty-free brands out of all brands: {num_cruelty_free_brands}")

# Print the percentage of cruelty-free brands without special characters
print(f"Percentage of cruelty-free brands: {percentage_cruelty_free:.2f}%")
# Out:
# Number of cruelty-free brands out of all brands: 19
# Percentage of cruelty-free brands: 1.13%
# C:\Users\shaan\AppData\Local\Temp\ipykernel_8952\3006896150.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   peta_df['Brand_info'] = peta_df['Brand_info'].str.replace('[^\w\s]+', '')
# C:\Users\shaan\AppData\Local\Temp\ipykernel_8952\3006896150.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   all_brands_ulta_df['Brand_info'] = all_brands_ulta_df['Brand_info'].str.replace('[^\w\s]+', '')

# %%
# Load data from CSV files
peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/peta.csv')
all_brands_ulta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_ulta.csv')

# Convert brand names to lowercase for case-insensitive comparison
peta_df['Brand_info'] = peta_df['Brand_info'].str.lower()
all_brands_ulta_df['Brand_info'] = all_brands_ulta_df['Brand_info'].str.lower()

# Check if brand names appear in both data frames
cruelty_free_brands_df = peta_df.merge(all_brands_ulta_df, how='inner', left_on='Brand_info', right_on='Brand_info')

# Get the names of all cruelty-free brands available on Ulta
cruelty_free_brand_names = cruelty_free_brands_df['Brand_info'].tolist()

# Print the names of all cruelty-free brands available on Ulta
print("Names of all cruelty-free brands available on Ulta:")
for brand in cruelty_free_brand_names:
    print(brand)
# Out:
# Names of all cruelty-free brands available on Ulta:
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# babo botanicals
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# dashing diva
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# earth harbor
# ...

# %%
# Read the CSV files into dataframes
peta_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/peta.csv')
all_brands_sephora_df = pd.read_csv('C:/Users/shaan/Desktop/big_data/bsc-big-data/Project/DataSets/all_brands_ulta.csv')

# Check if brand names appear in both data frames and print "True" if they appear in the peta_df dataframe
all_brands_sephora_df['appears_in_peta_df'] = all_brands_sephora_df['Brand_info'].isin(peta_df['Brand_info'])
print(all_brands_sephora_df['appears_in_peta_df'])
# display table
print(all_brands_sephora_df.head())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# 1678    False
# Name: appears_in_peta_df, Length: 1679, dtype: bool
#                      Brand_info  appears_in_peta_df
# 0                    about-face               False
# 1                   Ace BeautÃ©               False
# 2                         ACURE               False
# 3  B.Bungalow by Beachwaver Co.               False
# 4                         b.tan               False
